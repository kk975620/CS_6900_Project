# %% [markdown]
# <a href="https://colab.research.google.com/github/kk975620/CS_6900_Project/blob/main/SVM_OvR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC

# %%
dataset = pd.read_csv('PercentFeature.csv')
df = pd.DataFrame(dataset)
columns = df.columns.tolist()
for i in range(1,len(columns)):
  columns[i] = columns[i].split('1np_')[1].split('.')[0]
columns[0] ='NP'
df.columns = columns
df = df.T
df.columns = df.iloc[0]
df.drop(index=df.index[0], 
        axis=0, 
        inplace=True)
cols = df.columns
df
# Out:
# NP         CHD2 CTCF-7BWu  enhancer     EP300  h3k27me3  H3K36me3   H3K9me3  \
# f10a2  0.067043   0.39774  0.263842  0.208851  0.105085  0.223917  0.155556
# f10a3  0.066978  0.415567  0.290797  0.227493  0.113412  0.243194  0.157675
# f10a4  0.076307  0.454091  0.316738  0.245434   0.12059  0.258944  0.148862
# f10a5  0.064214  0.384975  0.273067  0.216958  0.101933  0.247506  0.165835
# f10a6   0.04898   0.35102  0.227211  0.167347  0.095238  0.155102  0.171429
# ...         ...       ...       ...       ...       ...       ...       ...
# f9g1   0.063757  0.400196  0.259931  0.198627   0.11182  0.232467  0.158411
# f9g2   0.067926   0.40888  0.294897  0.224652  0.110007  0.246521  0.153082
# f9g3   0.076947  0.414573  0.321922  0.253141  0.112751  0.267274  0.144786
# f9g4   0.087297  0.479015   0.34751  0.261332  0.120313  0.242865  0.128707
# f9g5   0.078552   0.44188  0.321406  0.244548  0.124921  0.255346  0.153928
#
# ...

# %%
X =df.drop(['Cluster'], axis = 1)
y = df['Cluster']
y=y.astype('int')

from sklearn import preprocessing
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))

X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=4)

# %%
y_test_df = pd.DataFrame(y_test)

# %%
OvR_SVC_clf = OneVsRestClassifier(SVC())
OvR_SVC_clf.fit(X_train, y_train)
y_pred = OvR_SVC_clf.predict(X_test)
print('Accuracy of OvR Classifier with SVC: {:.2f}'.format(accuracy_score(y_test, y_pred)))
# Out:
# Accuracy of OvR Classifier with SVC: 0.23

# %%
new_df = pd.DataFrame(X_test)
# new_df.columns=columns
x = y_test.to_list()
type(x)
new_df['Clusters']=x
new_df.columns = cols
new_df['y_pred'] = y_pred
len(cols)
new_df
#new_df[['Cluster','y_pred']]
# Out:
# NP      CHD2  CTCF-7BWu  enhancer     EP300  h3k27me3  H3K36me3   H3K9me3  \
# 0  -0.684834  -1.430471 -1.054028 -1.117389 -1.022847 -0.954683  0.759581
# 1  -0.157078   0.517486  0.872230  0.709759  0.062223  0.305029  0.353637
# 2  -0.979584  -0.980890 -0.993940 -0.883522 -0.495377 -0.884784  0.104517
# 3  -0.422970  -0.717102 -0.731613 -0.604253 -0.620896 -0.785918  0.645972
# 4  -0.259133  -0.197408  0.082172  0.163358 -0.100013 -0.526104 -1.088439
# ..       ...        ...       ...       ...       ...       ...       ...
# 92  0.301151   0.825307  0.712000  0.487219  0.443247  0.702348  0.755399
# 93 -0.323933  -0.090200 -0.125088 -0.221713 -0.484356 -0.218415 -0.374865
# 94 -0.669105  -0.037260 -0.189999 -0.472495 -0.220308 -0.530841 -1.008580
# 95  0.717256   1.353208  1.338892  0.751426  1.341606  0.655180  2.515216
# 96 -2.354289  -3.541686 -2.881984 -3.377354 -3.031966 -2.429719  2.612273
#
# NP      MAFK     med12     4-Oct  RNAPII-s2p  RNAPII-S5p  RNAPII-S7p  \
# ...
